# %%
# SmartBank Customer Churn Analysis

This project performs Exploratory Data Analysis (EDA) on customer demographic data to understand patterns 
that may influence customer churn.

## Objectives
- Understand the dataset structure
- Perform exploratory data analysis
- Identify patterns in customer demographics
- Prepare the dataset for machine learning

# %%
## Import Libraries and Load Dataset

# %%
import pandas as pd

df = pd.read_excel("Customer_Churn_Data_Large.xlsx")

df.head()
# Out:
#    CustomerID  Age Gender MaritalStatus IncomeLevel
# 0           1   62      M        Single         Low
# 1           2   65      M       Married         Low
# 2           3   18      M        Single         Low
# 3           4   21      M       Widowed         Low
# 4           5   21      M      Divorced      Medium

# %%
## Dataset Overview

Understanding the structure of the dataset including number of rows, columns, and data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     1000 non-null   int64
#  1   Age            1000 non-null   int64
#  2   Gender         1000 non-null   object
#  3   MaritalStatus  1000 non-null   object
#  4   IncomeLevel    1000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB

# %%
## Missing Value Analysis

Checking whether the dataset contains missing values.

# %%
df.isnull().sum()
# Out:
# CustomerID       0
# Age              0
# Gender           0
# MaritalStatus    0
# IncomeLevel      0
# dtype: int64

# %%
## Statistical Summary

Analyzing numerical statistics such as mean, median, minimum, and maximum values.

# %%
df.describe()
# Out:
#         CustomerID          Age
# count  1000.000000  1000.000000
# mean    500.500000    43.267000
# std     288.819436    15.242311
# min       1.000000    18.000000
# 25%     250.750000    30.000000
# 50%     500.500000    43.000000
# 75%     750.250000    56.000000
# max    1000.000000    69.000000

# %%
## Age Distribution

Visualizing the distribution of customer ages using a histogram.

# %%
import matplotlib.pyplot as plt

plt.hist(df['Age'], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
## Gender Distribution

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    513
# M    487
# Name: count, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='bar')

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")
plt.show()

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Widowed     276
# Married     261
# Divorced    248
# Single      215
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts().plot(kind='bar')

plt.title("Marital Status Distribution")
plt.xlabel("Marital Status")
plt.ylabel("Customers")
plt.show()

# %%
df['IncomeLevel'].value_counts()
# Out:
# IncomeLevel
# High      349
# Medium    326
# Low       325
# Name: count, dtype: int64

# %%
df['IncomeLevel'].value_counts().plot(kind='bar')

plt.title("Income Level Distribution")
plt.xlabel("Income Level")
plt.ylabel("Customers")
plt.show()

# %%
plt.boxplot(df['Age'])
plt.title("Age Boxplot")
plt.show()

# %%
## Final Prepared Dataset

After preprocessing and encoding categorical variables, the dataset is ready for machine learning models.

# %%
The dataset was successfully analyzed using exploratory data analysis techniques. Key demographic characteristics 
such as age, gender, marital status, and income level were examined. The dataset contained no missing values and 
required minimal cleaning. Categorical variables were encoded into numerical format to prepare the data for future 
machine learning modeling.
